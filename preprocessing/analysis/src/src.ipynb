# %%
import pandas as pd

# %%
def read_misconduct():
    df = pd.read_csv("../../merge/data/output/misconduct_georgia.csv")
    return df 

df = read_misconduct()

df
# Out:
#       case_number  date_opened                            agcy_name  \
# 0      0107531114   2014-11-17   MERIWETHER COUNTY SHERIFF'S OFFICE
# 1      0107531114   2014-11-17   MERIWETHER COUNTY SHERIFF'S OFFICE
# 2      0103860212   2012-02-09           SAVANNAH POLICE DEPARTMENT
# 3      0103860212   2012-02-09           SAVANNAH POLICE DEPARTMENT
# 4      0101901112   2012-11-15         IRWIN COUNTY SHERIFFS OFFICE
# ...           ...          ...                                  ...
# 60770  0207461121   2021-11-17        WALTON COUNTY SHERIFFS OFFICE
# 60771  0207461121   2021-11-17        WALTON COUNTY SHERIFFS OFFICE
# 60772  0207461121   2021-11-17        WALTON COUNTY SHERIFFS OFFICE
# 60773  0070500115   2015-01-08      FRANKLIN COUNTY SHERIFFS OFFICE
# 60774  0202160222   2022-02-14           GLYNN-BRUNSWICK 911 CENTER
#
#                                         allegation incident_date      uid  \
# 0        PERFORMING DUTIES WITHOUT BEING CERTIFIED    0000-00-00  c000059
# ...
